# %%
import tensorflow as tf

# %%
import tensorflow.keras
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras import backend as K

# the data, split between train and test sets
(x_train, y_train), (x_test, y_test) = mnist.load_data()

print(x_train.shape, y_train.shape)
# Out:
# (60000, 28, 28) (60000,)

# %%
x_train = x_train.reshape(x_train.shape[0], 28, 28, 1)
x_test = x_test.reshape(x_test.shape[0], 28, 28, 1)
input_shape = (28, 28, 1)

# convert class vectors to binary class matrices
y_train = keras.utils.np_utils.to_categorical(y_train)
y_test = keras.utils.np_utils.to_categorical(y_test)

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# Out:
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples

# %%
batch_size = 128
num_classes = 10
epochs = 10

model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3),activation='relu',input_shape=input_shape))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss=keras.losses.categorical_crossentropy,optimizer=tensorflow.keras.optimizers.Adadelta(),metrics=['accuracy'])

# %%
hist = model.fit(x_train, y_train,batch_size=batch_size,epochs=epochs,verbose=1,validation_data=(x_test, y_test))
print("The model has successfully trained")

model.save('mnist.h5')
print("Saving the model as mnist.h5")
# Out:
# Epoch 1/10
# 469/469 [==============================] - 167s 353ms/step - loss: 2.2733 - accuracy: 0.1826 - val_loss: 2.2229 - val_accuracy: 0.4073
# Epoch 2/10
# 469/469 [==============================] - 164s 349ms/step - loss: 2.1928 - accuracy: 0.3293 - val_loss: 2.1259 - val_accuracy: 0.5957
# Epoch 3/10
# 469/469 [==============================] - 164s 350ms/step - loss: 2.0917 - accuracy: 0.4491 - val_loss: 1.9957 - val_accuracy: 0.6964
# Epoch 4/10
# 469/469 [==============================] - 165s 352ms/step - loss: 1.9531 - accuracy: 0.5314 - val_loss: 1.8160 - val_accuracy: 0.7464
# Epoch 5/10
# 469/469 [==============================] - 167s 357ms/step - loss: 1.7657 - accuracy: 0.5939 - val_loss: 1.5854 - val_accuracy: 0.7662
# Epoch 6/10
# 469/469 [==============================] - 167s 356ms/step - loss: 1.5499 - accuracy: 0.6330 - val_loss: 1.3314 - val_accuracy: 0.7848
# Epoch 7/10
# 469/469 [==============================] - 165s 353ms/step - loss: 1.3319 - accuracy: 0.6655 - val_loss: 1.1002 - val_accuracy: 0.8049
# Epoch 8/10
# 469/469 [==============================] - 164s 350ms/step - loss: 1.1510 - accuracy: 0.6928 - val_loss: 0.9197 - val_accuracy: 0.8219
# Epoch 9/10
# 469/469 [==============================] - 164s 349ms/step - loss: 1.0141 - accuracy: 0.7171 - val_loss: 0.7890 - val_accuracy: 0.8357
# Epoch 10/10
# 469/469 [==============================] - 165s 351ms/step - loss: 0.9100 - accuracy: 0.7357 - val_loss: 0.6959 - val_accuracy: 0.8437
# The model has successfully trained
# Saving the model as mnist.h5
